# %%
import pandas as pd
import os
import re

# %%
df = pd.DataFrame(columns=["Area", "Corda", "Envergadura", "Geracao", "Pontuacao", "File"])

pasta = "./Banco_asas/asas_todas2"
for filename in os.listdir(pasta):
    if filename.endswith(".avl"):
        with open(f"{pasta}/{filename}",'r') as asa:
            texto_asa = asa.readlines()
            dados = re.findall(r"\d\.\d\d\d\d\d\d",texto_asa[3].strip("\n"))
            dados.append(filename.split("_")[1]) # Geracao
            dados.append(texto_asa[-1][1:]) # Pontuacao
            dados.append(filename)
            df = pd.concat([pd.DataFrame([dados],columns=["Area", "Corda", "Envergadura", "Geracao", "Pontuacao", "File"]),df], axis=0)

            df["Area"] = pd.to_numeric(df["Area"])
df["Corda"] = pd.to_numeric(df["Corda"])
df["Envergadura"] = pd.to_numeric(df["Envergadura"])
df["Geracao"] = pd.to_numeric(df["Geracao"])
df["Pontuacao"] = pd.to_numeric(df["Pontuacao"])
df = df.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-97ab6ba4149a> in <module>
#       2
#       3 pasta = "./Banco_asas/asas_todas2"
# ----> 4 for filename in os.listdir(pasta):
#       5     if filename.endswith(".avl"):
#       6         with open(f"{pasta}/{filename}",'r') as asa:
#
# FileNotFoundError: [WinError 3] O sistema não pode encontrar o caminho especificado: './Banco_asas/asas_todas2'

# %%
df
# Out:
#           Area     Corda  Envergadura  Geracao  Pontuacao  \
# 0     1.442405  0.372962       3.7128        9  16.683879
# 1     1.441070  0.372962       3.7092        9  16.692628
# 2     1.115031  0.302186       3.8496        9  16.991974
# 3     1.334267  0.354547       3.9828        9  17.769530
# 4     1.348817  0.364301       3.9864        9  17.809604
# ...        ...       ...          ...      ...        ...
# 9752  2.498955  0.276835       8.4740        0   2.638225
# 9753  1.339830  0.245187       6.0140        0  21.008428
# 9754  3.286202  0.328084       0.0880        0 -28.744277
# 9755  2.114725  0.370296       6.2900        0  12.787678
# 9756  2.072081  0.281897       7.3640        0  13.705144
#
#                            File
# 0      geracao_9_individuo9.avl
# 1      geracao_9_individuo8.avl
# 2      geracao_9_individuo7.avl
# 3      geracao_9_individuo6.avl
# 4      geracao_9_individuo5.avl
# ...                         ...
# 9752  geracao_0_individuo12.avl
# 9753  geracao_0_individuo11.avl
# 9754  geracao_0_individuo10.avl
# 9755   geracao_0_individuo1.avl
# 9756   geracao_0_individuo0.avl
#
# [9757 rows x 6 columns]

# %%
df.groupby("Geracao").count()["Area"].plot()
# Out:
# <AxesSubplot:xlabel='Geracao'>

# %%
df.groupby("Geracao").mean()["Area"].plot()
# Out:
# <AxesSubplot:xlabel='Geracao'>

# %%
df.groupby("Geracao").mean()["Envergadura"].plot()
# Out:
# <AxesSubplot:xlabel='Geracao'>

# %%
df.groupby("Geracao").max()["Pontuacao"].plot()
# Out:
# <AxesSubplot:xlabel='Geracao'>

# %%
df[df["Geracao"]==243]
# Out:
#           Area     Corda  Envergadura  Geracao  Pontuacao  \
# 3360  1.326572  0.328368       4.1196      243  18.309968
# 3361  1.326572  0.328368       4.1196      243  18.309968
# 3362  1.326572  0.328368       4.1196      243  18.309968
# 3363  1.326572  0.328368       4.1196      243  18.309968
# 3364  1.326572  0.328368       4.1196      243  18.309968
# 3365  1.326572  0.328368       4.1196      243  18.309968
# 3366  1.331636  0.331208       4.1196      243  18.289879
